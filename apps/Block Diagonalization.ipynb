# %% [markdown]
# # Simulation Results for the Enhanced Block Diagonalization algorithm

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Now we import some modules we use and add the PyPhysim to the python path.

# %%
import sys
sys.path.append("/home/darlan/cvs_files/pyphysim")
# xxxxxxxxxx Import Statements xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
from util.simulations import SimulationRunner, SimulationParameters, SimulationResults, Result
from comm import modulators, channels
from util.conversion import dB2Linear
from util import misc
from ia import ia
import numpy as np
from pprint import pprint

from apps.simulate_comp import plot_spectral_efficience_all_metrics, plot_per_all_metrics
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx

# %% [markdown]
# Now we set the transmit parameters and load the simulation results from the file corresponding to those transmit parameters.

# %%
results_filename = 'bd_results'
results = SimulationResults.load_from_file('{0}{1}'.format(results_filename, '.pickle'))
SNR = results.params['SNR']

# %% [markdown]
# ## Results for external interference of 10dBm

# %%
Pe_dBm = 10
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(20,7))
fig = plot_spectral_efficience_all_metrics(results, Pe_dBm, ax[0])
fig = plot_per_all_metrics(results, Pe_dBm, ax[1])

# %% [markdown]
# ## Results for external interference of 0dBm

# %%
Pe_dBm = 0
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(20,7))
fig = plot_spectral_efficience_all_metrics(results, Pe_dBm, ax[0])
fig = plot_per_all_metrics(results, Pe_dBm, ax[1])

# %% [markdown]
# ## Results for external interference of -10dBm

# %%
Pe_dBm = -10
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(20,7))
fig = plot_spectral_efficience_all_metrics(results, Pe_dBm, ax[0])
fig = plot_per_all_metrics(results, Pe_dBm, ax[1])
